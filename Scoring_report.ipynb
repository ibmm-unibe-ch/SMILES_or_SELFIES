# %%
import pandas as pd
import os
from constants import TASK_PATH, TOKENIZER_SUFFIXES, MOLNET_DIRECTORY

classification_scores = []
regression_scores = []
for tokenizer_suffix in TOKENIZER_SUFFIXES:
    for task in MOLNET_DIRECTORY.keys():
        task_tokenizer_path = TASK_MODEL_PATH/task/tokenizer_suffix/
        if task_tokenizer_path.exists():
            for hyperparameter_path in glob(str(task_tokenizer_path) + "/*", recursive=True):
                scores_path = hyperparameter_path+"scores.csv"
                print(scores_path)
                if not scores_path.is_file():
                    continue
                new_score_df = pd.read_csv(scores_path)
                if list(new_score_df.task_type)[0] == "classification":
                    classification_scores.append(new_score_df)
                else:
                    regression_scores.append(new_score_df)

regression_scores = pd.concat(regression_scores, axis = 0, sort = False)
classification_scores = pd.concat(classification_scores, axis = 0, sort = False)

# %%
columns = list(regression_scores.columns[-3:])
columns.extend(regression_scores.columns[:-3])

regression_scores.sort_values(["task", "tokenizer"])[columns].drop(["model", "Unnamed: 0", "task_type"], axis="columns")
# Out:
#               task              tokenizer  mean_absolute_error  max_error  \
# 0  bace_regression           selfies_atom             0.725042   2.299630
# 0  bace_regression  selfies_sentencepiece             1.117676   3.605957
# 0  bace_regression            smiles_atom             0.857770   3.031126
# 0  bace_regression   smiles_sentencepiece             1.088710   2.987920
# 0        clearance           selfies_atom             0.891862   2.944291
# 0        clearance  selfies_sentencepiece             1.096108   2.479986
# 0        clearance            smiles_atom             0.955795   2.785223
# 0        clearance   smiles_sentencepiece             1.062879   2.280607
# 0          delaney           selfies_atom             0.452987   1.679699
# 0          delaney  selfies_sentencepiece             0.622208   1.754844
# 0          delaney            smiles_atom             0.360039   1.184675
# 0          delaney   smiles_sentencepiece             0.588780   2.099146
# 0             lipo           selfies_atom             0.568438   2.369925
# 0             lipo  selfies_sentencepiece             0.755902   3.947413
# 0             lipo            smiles_atom             0.565659   2.839077
# 0             lipo   smiles_sentencepiece             0.661779   2.690093
# 0              qm7           selfies_atom             0.704351   3.082740
# 0              qm7  selfies_sentencepiece             0.816240   3.349491
# 0              qm7            smiles_atom             0.679752   2.993359
# 0              qm7   smiles_sentencepiece             0.773665   3.206568
#
#    mean_squared_error  rectified_mean_squared_error
# 0            0.803044                      0.896127
# 0            1.725888                      1.313731
# 0            1.076545                      1.037567
# 0            1.621047                      1.273203
# 0            1.367467                      1.169388
# 0            1.528868                      1.236474
# 0            1.336323                      1.155994
# 0            1.464011                      1.209963
# 0            0.315294                      0.561510
# 0            0.570939                      0.755605
# 0            0.214978                      0.463657
# 0            0.569317                      0.754531
# 0            0.509693                      0.713928
# 0            0.884808                      0.940642
# 0            0.525620                      0.724996
# 0            0.654418                      0.808961
# 0            0.760167                      0.871875
# 0            1.016289                      1.008111
# 0            0.719404                      0.848177
# 0            0.951141                      0.975265

# %%
columns = list(classification_scores.columns[-3:])
columns.extend(classification_scores.columns[:-3])

classification_scores.sort_values(["task", "tokenizer"])[columns].drop(["model", "Unnamed: 0", "task_type"], axis="columns")
# Out:
#                   task              tokenizer   ROC_AUC  average_precision  \
# 0  bace_classification           selfies_atom  0.812319           0.860801
# 0  bace_classification  selfies_sentencepiece  0.621014           0.683375
# 0  bace_classification            smiles_atom  0.771739           0.833602
# 0  bace_classification   smiles_sentencepiece  0.643297           0.725607
# 0                 bbbp           selfies_atom  0.689276           0.608683
# 0                 bbbp            smiles_atom  0.717603           0.627038
# 0                 bbbp   smiles_sentencepiece  0.716447           0.672517
# 0              clintox           selfies_atom  0.650725           0.122400
# 0              clintox  selfies_sentencepiece  0.575362           0.080980
# 0              clintox            smiles_atom  0.631884           0.104592
# 0              clintox   smiles_sentencepiece  0.529710           0.086062
# 0                  hiv           selfies_atom  0.768906           0.332613
# 0                  hiv  selfies_sentencepiece  0.723983           0.205500
# 0                  hiv            smiles_atom  0.761078           0.281923
# 0                  hiv   smiles_sentencepiece  0.760145           0.175746
# 0                tox21           selfies_atom  0.702189           0.212876
# 0                tox21  selfies_sentencepiece  0.635436           0.175053
# 0                tox21            smiles_atom  0.682526           0.193719
# 0                tox21   smiles_sentencepiece  0.547714           0.139003
#
#    F1_score  accuracy_score
# 0  0.777778        0.736842
# 0  0.717172        0.631579
# 0  0.708861        0.697368
# 0  0.524138        0.546053
# 0  0.454545        0.588235
# 0  0.510067        0.642157
# 0  0.476821        0.612745
# 0  0.000000        0.932432
# 0  0.000000        0.932432
# 0  0.000000        0.932432
# 0  0.000000        0.932432
# 0  0.372549        0.968819
# 0  0.198758        0.968575
# 0  0.292398        0.970524
# 0  0.057143        0.967844
# 0  0.026667        0.906888
# 0  0.000000        0.908163
# 0  0.000000        0.908163
# 0  0.000000        0.908163
