# %%
import pandas as pd
import os
from constants import TASK_MODEL_PATH, TOKENIZER_SUFFIXES, MOLNET_DIRECTORY, PROJECT_PATH, DESCRIPTORS

from glob import glob
from pathlib import Path
pd.set_option('display.max_rows', 500)

classification_scores = []
regression_scores = []
#TOKENIZER_SUFFIXES+=["smiles_isomers_atom","smiles_isomers_sentencepiece","selfies_isomers_atom","selfies_isomers_sentencepiece"]
for tokenizer_suffix in TOKENIZER_SUFFIXES:
    for task in MOLNET_DIRECTORY.keys():
        task_tokenizer_path = TASK_MODEL_PATH/task/tokenizer_suffix
        if task.startswith("bace"):
            task_tokenizer_path = Path("/data/jgut/SoS_models")/task/tokenizer_suffix
            print(task_tokenizer_path)
        if task_tokenizer_path.exists():
            for hyperparameter_path in glob(str(task_tokenizer_path) + "/*", recursive=True):
                scores_path = hyperparameter_path+"/scores.csv"
                print(scores_path)
                if not Path(scores_path).is_file():
                    continue
                new_score_df = pd.read_csv(scores_path)
                if list(new_score_df.task_type)[0] == "classification":
                    classification_scores.append(new_score_df)
                else:
                    regression_scores.append(new_score_df)

regression_scores = pd.concat(regression_scores, axis = 0, sort = False)
classification_scores = pd.concat(classification_scores, axis = 0, sort = False)
# Out:
# /data/jgut/SoS_models/bace_classification/smiles_atom_isomers
# /data/jgut/SoS_models/bace_classification/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_isomers
# /data/jgut/SoS_models/bace_regression/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_atom_standard
# /data/jgut/SoS_models/bace_classification/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_standard
# /data/jgut/SoS_models/bace_regression/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_isomers
# /data/jgut/SoS_models/bace_classification/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_isomers
# /data/jgut/SoS_models/bace_regression/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_standard
# /data/jgut/SoS_models/bace_classification/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_standard
# /data/jgut/SoS_models/bace_regression/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/smiles_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_isomers
# /data/jgut/SoS_models/bace_classification/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_isomers
# /data/jgut/SoS_models/bace_regression/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_standard
# /data/jgut/SoS_models/bace_classification/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_standard
# /data/jgut/SoS_models/bace_regression/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_isomers
# /data/jgut/SoS_models/bace_classification/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_isomers
# /data/jgut/SoS_models/bace_regression/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_standard
# /data/jgut/SoS_models/bace_classification/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_standard
# /data/jgut/SoS_models/bace_regression/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/selfies_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_isomers
# /data/jgut/SoS_models/bace_classification/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_isomers
# /data/jgut/SoS_models/bace_regression/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_standard
# /data/jgut/SoS_models/bace_classification/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_standard
# /data/jgut/SoS_models/bace_regression/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_atom_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_isomers
# /data/jgut/SoS_models/bace_classification/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_isomers
# /data/jgut/SoS_models/bace_regression/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_isomers/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_isomers/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_isomers/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_standard
# /data/jgut/SoS_models/bace_classification/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_classification/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_standard
# /data/jgut/SoS_models/bace_regression/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bace_regression/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/bbbp/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clearance/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/clintox/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/delaney/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/hiv/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/lipo/own_trained_standard/5e-06_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_standard/5e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_standard/1e-05_0.2_based_norm/scores.csv
# /data/jgut/SoS_models/tox21/own_trained_standard/5e-06_0.2_based_norm/scores.csv

# %%
columns = list(regression_scores.columns[-3:])
columns.extend(regression_scores.columns[:-3])

regression_scores.sort_values(["task", "tokenizer"])[columns].sort_values(["mean_absolute_error"]).drop(["model_size", "Unnamed: 0", "task_type"], axis="columns").groupby(["task", "tokenizer"]).first()
# Out:
#                                           max_error  mean_squared_error  \
# task            tokenizer
# bace_regression own_atom_isomers           3.061143            1.352640
#                 own_atom_standard          3.223478            1.301526
#                 own_trained_isomers        3.083954            1.290290
#                 own_trained_standard       3.182139            1.279814
#                 selfies_atom_isomers       2.506134            0.589982
#                 selfies_atom_standard      2.679491            0.629948
#                 selfies_trained_isomers    2.398314            0.601272
#                 selfies_trained_standard   3.193220            1.520639
#                 smiles_atom_isomers        2.551311            0.559948
#                 smiles_atom_standard       2.612378            0.550636
#                 smiles_trained_isomers     3.028330            1.460758
#                 smiles_trained_standard    3.003850            1.500746
# clearance       own_atom_isomers           2.261605            1.579354
#                 own_atom_standard          2.234422            1.564000
#                 own_trained_isomers        2.077589            1.537866
#                 own_trained_standard       2.089594            1.538147
#                 selfies_atom_isomers       3.421538            1.657343
#                 selfies_atom_standard      3.016456            1.600125
#                 selfies_trained_isomers    3.507671            1.681693
#                 selfies_trained_standard   3.458014            1.699902
#                 smiles_atom_isomers        3.484492            1.478648
#                 smiles_atom_standard       3.123581            1.414283
#                 smiles_trained_isomers     2.559994            1.213581
#                 smiles_trained_standard    2.322544            1.491789
# delaney         own_atom_isomers           2.411606            0.888064
#                 own_atom_standard          2.535092            0.888188
#                 own_trained_isomers        2.451027            0.912082
#                 own_trained_standard       2.556707            0.932320
#                 selfies_atom_isomers       1.514164            0.216696
#                 selfies_atom_standard      1.560331            0.251758
#                 selfies_trained_isomers    1.469231            0.301327
#                 selfies_trained_standard   1.374690            0.317169
#                 smiles_atom_isomers        1.414895            0.206804
#                 smiles_atom_standard       1.100976            0.198883
#                 smiles_trained_isomers     2.286607            0.417935
#                 smiles_trained_standard    1.880614            0.442411
# lipo            own_atom_isomers           2.919299            0.826430
#                 own_atom_standard          2.913176            0.831419
#                 own_trained_isomers        2.945911            0.822103
#                 own_trained_standard       2.965844            0.819812
#                 selfies_atom_isomers       3.024261            0.701632
#                 selfies_atom_standard      2.733305            0.671469
#                 selfies_trained_isomers    2.888786            0.692471
#                 selfies_trained_standard   2.688689            0.646087
#                 smiles_atom_isomers        2.564487            0.574514
#                 smiles_atom_standard       2.279807            0.599193
#                 smiles_trained_isomers     2.629400            0.572394
#                 smiles_trained_standard    2.407512            0.558958
#
#                                           rectified_mean_squared_error  \
# task            tokenizer
# bace_regression own_atom_isomers                              1.163030
#                 own_atom_standard                             1.140844
#                 own_trained_isomers                           1.135909
#                 own_trained_standard                          1.131289
#                 selfies_atom_isomers                          0.768103
#                 selfies_atom_standard                         0.793693
#                 selfies_trained_isomers                       0.775417
#                 selfies_trained_standard                      1.233142
#                 smiles_atom_isomers                           0.748297
#                 smiles_atom_standard                          0.742048
#                 smiles_trained_isomers                        1.208618
#                 smiles_trained_standard                       1.225049
# clearance       own_atom_isomers                              1.256724
#                 own_atom_standard                             1.250600
#                 own_trained_isomers                           1.240107
#                 own_trained_standard                          1.240220
#                 selfies_atom_isomers                          1.287378
#                 selfies_atom_standard                         1.264961
#                 selfies_trained_isomers                       1.296801
#                 selfies_trained_standard                      1.303803
#                 smiles_atom_isomers                           1.215997
#                 smiles_atom_standard                          1.189236
#                 smiles_trained_isomers                        1.101627
#                 smiles_trained_standard                       1.221388
# delaney         own_atom_isomers                              0.942371
#                 own_atom_standard                             0.942437
#                 own_trained_isomers                           0.955030
#                 own_trained_standard                          0.965567
#                 selfies_atom_isomers                          0.465506
#                 selfies_atom_standard                         0.501755
#                 selfies_trained_isomers                       0.548933
#                 selfies_trained_standard                      0.563178
#                 smiles_atom_isomers                           0.454757
#                 smiles_atom_standard                          0.445963
#                 smiles_trained_isomers                        0.646479
#                 smiles_trained_standard                       0.665139
# lipo            own_atom_isomers                              0.909082
#                 own_atom_standard                             0.911822
#                 own_trained_isomers                           0.906699
#                 own_trained_standard                          0.905435
#                 selfies_atom_isomers                          0.837634
#                 selfies_atom_standard                         0.819432
#                 selfies_trained_isomers                       0.832148
#                 selfies_trained_standard                      0.803796
#                 smiles_atom_isomers                           0.757967
#                 smiles_atom_standard                          0.774076
#                 smiles_trained_isomers                        0.756567
#                 smiles_trained_standard                       0.747635
#
#                                           learning_rate  dropout data_type  \
# task            tokenizer
# bace_regression own_atom_isomers               0.000050      0.2      norm
#                 own_atom_standard              0.000050      0.2      norm
#                 own_trained_isomers            0.000010      0.2      norm
#                 own_trained_standard           0.000050      0.2      norm
#                 selfies_atom_isomers           0.000050      0.2      norm
#                 selfies_atom_standard          0.000050      0.2      norm
#                 selfies_trained_isomers        0.000050      0.2      norm
#                 selfies_trained_standard       0.000050      0.2      norm
#                 smiles_atom_isomers            0.000050      0.2      norm
#                 smiles_atom_standard           0.000005      0.2      norm
#                 smiles_trained_isomers         0.000050      0.2      norm
#                 smiles_trained_standard        0.000050      0.2      norm
# clearance       own_atom_isomers               0.000005      0.2      norm
#                 own_atom_standard              0.000005      0.2      norm
#                 own_trained_isomers            0.000010      0.2      norm
#                 own_trained_standard           0.000010      0.2      norm
#                 selfies_atom_isomers           0.000005      0.2      norm
#                 selfies_atom_standard          0.000010      0.2      norm
#                 selfies_trained_isomers        0.000010      0.2      norm
#                 selfies_trained_standard       0.000010      0.2      norm
#                 smiles_atom_isomers            0.000005      0.2      norm
#                 smiles_atom_standard           0.000010      0.2      norm
#                 smiles_trained_isomers         0.000050      0.2      norm
#                 smiles_trained_standard        0.000050      0.2      norm
# delaney         own_atom_isomers               0.000005      0.2      norm
#                 own_atom_standard              0.000010      0.2      norm
#                 own_trained_isomers            0.000050      0.2      norm
#                 own_trained_standard           0.000010      0.2      norm
#                 selfies_atom_isomers           0.000010      0.2      norm
#                 selfies_atom_standard          0.000005      0.2      norm
#                 selfies_trained_isomers        0.000050      0.2      norm
#                 selfies_trained_standard       0.000010      0.2      norm
#                 smiles_atom_isomers            0.000005      0.2      norm
#                 smiles_atom_standard           0.000050      0.2      norm
#                 smiles_trained_isomers         0.000010      0.2      norm
#                 smiles_trained_standard        0.000050      0.2      norm
# lipo            own_atom_isomers               0.000050      0.2      norm
#                 own_atom_standard              0.000050      0.2      norm
#                 own_trained_isomers            0.000050      0.2      norm
#                 own_trained_standard           0.000010      0.2      norm
#                 selfies_atom_isomers           0.000005      0.2      norm
#                 selfies_atom_standard          0.000050      0.2      norm
#                 selfies_trained_isomers        0.000005      0.2      norm
#                 selfies_trained_standard       0.000050      0.2      norm
#                 smiles_atom_isomers            0.000050      0.2      norm
#                 smiles_atom_standard           0.000050      0.2      norm
#                 smiles_trained_isomers         0.000050      0.2      norm
#                 smiles_trained_standard        0.000050      0.2      norm
#
#                                           mean_absolute_error
# task            tokenizer
# bace_regression own_atom_isomers                     0.962068
#                 own_atom_standard                    0.924354
#                 own_trained_isomers                  0.938909
#                 own_trained_standard                 0.923487
#                 selfies_atom_isomers                 0.624994
#                 selfies_atom_standard                0.638406
#                 selfies_trained_isomers              0.594713
#                 selfies_trained_standard             0.988781
#                 smiles_atom_isomers                  0.604476
#                 smiles_atom_standard                 0.590270
#                 smiles_trained_isomers               0.972107
#                 smiles_trained_standard              0.983399
# clearance       own_atom_isomers                     1.097039
#                 own_atom_standard                    1.095640
#                 own_trained_isomers                  1.101739
#                 own_trained_standard                 1.101006
#                 selfies_atom_isomers                 0.985131
#                 selfies_atom_standard                0.999374
#                 selfies_trained_isomers              0.992005
#                 selfies_trained_standard             0.989158
#                 smiles_atom_isomers                  0.937153
#                 smiles_atom_standard                 0.939397
#                 smiles_trained_isomers               0.929991
#                 smiles_trained_standard              1.082935
# delaney         own_atom_isomers                     0.738737
#                 own_atom_standard                    0.740853
#                 own_trained_isomers                  0.737825
#                 own_trained_standard                 0.735054
#                 selfies_atom_isomers                 0.377537
#                 selfies_atom_standard                0.401156
#                 selfies_trained_isomers              0.432916
#                 selfies_trained_standard             0.463486
#                 smiles_atom_isomers                  0.351919
#                 smiles_atom_standard                 0.345127
#                 smiles_trained_isomers               0.481507
#                 smiles_trained_standard              0.511471
# lipo            own_atom_isomers                     0.748908
#                 own_atom_standard                    0.752140
#                 own_trained_isomers                  0.746357
#                 own_trained_standard                 0.744486
#                 selfies_atom_isomers                 0.675208
#                 selfies_atom_standard                0.660161
#                 selfies_trained_isomers              0.655289
#                 selfies_trained_standard             0.647264
#                 smiles_atom_isomers                  0.600233
#                 smiles_atom_standard                 0.623959
#                 smiles_trained_isomers               0.592999
#                 smiles_trained_standard              0.596993

# %%
from plotting import plot_scores
columns = list(classification_scores.columns[-3:])
columns.extend(classification_scores.columns[:-3])
tasks = classification_scores.task.unique()
tokenizers = classification_scores.tokenizer.unique()
scores = {}
for task in tasks:
    for tokenizer in tokenizers:
        if classification_scores[(classification_scores["tokenizer"]==tokenizer)&(classification_scores["task"]== task)]["ROC_AUC"].any():
            scores[tokenizer] = scores.get(tokenizer, []) + [max(classification_scores[(classification_scores["tokenizer"]==tokenizer)&(classification_scores["task"]== task)]["ROC_AUC"])]
#plot_scores(scores, tasks, "AUROC", Path("test/classification_report.svg"))
classification_scores.sort_values(["task", "tokenizer"])[columns].sort_values(["ROC_AUC"], ascending=False).drop(["model_size", "Unnamed: 0", "task_type"], axis="columns").groupby(["task", "tokenizer"]).first()
# Out:
#                                               average_precision  F1_score  \
# task                tokenizer
# bace_classification own_atom_isomers                   0.674956  0.000000
#                     own_atom_standard                  0.675005  0.000000
#                     own_trained_isomers                0.674857  0.000000
#                     own_trained_standard               0.674913  0.000000
#                     selfies_atom_isomers               0.854032  0.795455
#                     selfies_atom_standard              0.838349  0.756098
#                     selfies_trained_isomers            0.817742  0.739884
#                     selfies_trained_standard           0.856108  0.806452
#                     smiles_atom_isomers                0.835326  0.699387
#                     smiles_atom_standard               0.814936  0.739394
#                     smiles_trained_isomers             0.844777  0.810256
#                     smiles_trained_standard            0.759455  0.758294
# bbbp                own_atom_isomers                   0.512013  0.000000
#                     own_atom_standard                  0.511033  0.000000
#                     own_trained_isomers                0.512788  0.000000
#                     own_trained_standard               0.512013  0.000000
#                     selfies_atom_isomers               0.630471  0.268908
#                     selfies_atom_standard              0.624776  0.295082
#                     selfies_trained_isomers            0.643956  0.343750
#                     selfies_trained_standard           0.655233  0.411765
#                     smiles_atom_isomers                0.656223  0.338462
#                     smiles_atom_standard               0.650826  0.430556
#                     smiles_trained_isomers             0.660417  0.524390
#                     smiles_trained_standard            0.668535  0.417266
# clintox             own_atom_isomers                   0.077222  0.000000
#                     own_atom_standard                  0.076466  0.000000
#                     own_trained_isomers                0.073473  0.000000
#                     own_trained_standard               0.072871  0.000000
#                     selfies_atom_isomers               0.360662  0.142857
#                     selfies_atom_standard              0.368972  0.000000
#                     selfies_trained_isomers            0.363422  0.000000
#                     selfies_trained_standard           0.206275  0.000000
#                     smiles_atom_isomers                0.382564  0.153846
#                     smiles_atom_standard               0.399493  0.400000
#                     smiles_trained_isomers             0.306739  0.333333
#                     smiles_trained_standard            0.347795  0.000000
# hiv                 own_atom_isomers                   0.034327  0.000000
#                     own_atom_standard                  0.034615  0.000000
#                     own_trained_isomers                0.034346  0.000000
#                     own_trained_standard               0.034346  0.000000
#                     selfies_atom_isomers               0.190543  0.153846
#                     selfies_atom_standard              0.243954  0.194805
#                     selfies_trained_isomers            0.315901  0.185430
#                     selfies_trained_standard           0.225948  0.168831
#                     smiles_atom_isomers                0.289257  0.271605
#                     smiles_atom_standard               0.271851  0.292683
#                     smiles_trained_isomers             0.257784  0.303371
#                     smiles_trained_standard            0.262990  0.145695
# tox21               own_atom_isomers                   0.117173  0.000000
#                     own_atom_standard                  0.125383  0.000000
#                     own_trained_isomers                0.122172  0.000000
#                     own_trained_standard               0.116512  0.000000
#                     selfies_atom_isomers               0.173458  0.000000
#                     selfies_atom_standard              0.183819  0.000000
#                     selfies_trained_isomers            0.232696  0.000000
#                     selfies_trained_standard           0.236824  0.053333
#                     smiles_atom_isomers                0.165233  0.000000
#                     smiles_atom_standard               0.178378  0.000000
#                     smiles_trained_isomers             0.187299  0.000000
#                     smiles_trained_standard            0.181821  0.025641
#
#                                               accuracy_score  learning_rate  \
# task                tokenizer
# bace_classification own_atom_isomers                0.394737       0.000010
#                     own_atom_standard               0.394737       0.000005
#                     own_trained_isomers             0.394737       0.000010
#                     own_trained_standard            0.394737       0.000005
#                     selfies_atom_isomers            0.763158       0.000050
#                     selfies_atom_standard           0.736842       0.000050
#                     selfies_trained_isomers         0.703947       0.000010
#                     selfies_trained_standard        0.763158       0.000050
#                     smiles_atom_isomers             0.677632       0.000050
#                     smiles_atom_standard            0.717105       0.000050
#                     smiles_trained_isomers          0.756579       0.000050
#                     smiles_trained_standard         0.664474       0.000050
# bbbp                own_atom_isomers                0.524510       0.000010
#                     own_atom_standard               0.524510       0.000050
#                     own_trained_isomers             0.524510       0.000050
#                     own_trained_standard            0.524510       0.000050
#                     selfies_atom_isomers            0.573529       0.000005
#                     selfies_atom_standard           0.578431       0.000005
#                     selfies_trained_isomers         0.588235       0.000010
#                     selfies_trained_standard        0.607843       0.000050
#                     smiles_atom_isomers             0.578431       0.000010
#                     smiles_atom_standard            0.598039       0.000050
#                     smiles_trained_isomers          0.617647       0.000050
#                     smiles_trained_standard         0.602941       0.000010
# clintox             own_atom_isomers                0.932432       0.000010
#                     own_atom_standard               0.932432       0.000050
#                     own_trained_isomers             0.932432       0.000010
#                     own_trained_standard            0.932432       0.000010
#                     selfies_atom_isomers            0.918919       0.000050
#                     selfies_atom_standard           0.932432       0.000050
#                     selfies_trained_isomers         0.932432       0.000050
#                     selfies_trained_standard        0.932432       0.000010
#                     smiles_atom_isomers             0.925676       0.000050
#                     smiles_atom_standard            0.939189       0.000050
#                     smiles_trained_isomers          0.945946       0.000005
#                     smiles_trained_standard         0.932432       0.000005
# hiv                 own_atom_isomers                0.968331       0.000005
#                     own_atom_standard               0.968331       0.000005
#                     own_trained_isomers             0.968331       0.000005
#                     own_trained_standard            0.968331       0.000010
#                     selfies_atom_isomers            0.967844       0.000010
#                     selfies_atom_standard           0.969793       0.000005
#                     selfies_trained_isomers         0.970037       0.000010
#                     selfies_trained_standard        0.968819       0.000050
#                     smiles_atom_isomers             0.971255       0.000010
#                     smiles_atom_standard            0.971742       0.000010
#                     smiles_trained_isomers          0.969793       0.000010
#                     smiles_trained_standard         0.968575       0.000050
# tox21               own_atom_isomers                0.908163       0.000005
#                     own_atom_standard               0.908163       0.000005
#                     own_trained_isomers             0.908163       0.000005
#                     own_trained_standard            0.908163       0.000050
#                     selfies_atom_isomers            0.908163       0.000050
#                     selfies_atom_standard           0.908163       0.000050
#                     selfies_trained_isomers         0.908163       0.000050
#                     selfies_trained_standard        0.909439       0.000050
#                     smiles_atom_isomers             0.908163       0.000005
#                     smiles_atom_standard            0.908163       0.000005
#                     smiles_trained_isomers          0.908163       0.000005
#                     smiles_trained_standard         0.903061       0.000050
#
#                                               dropout data_type   ROC_AUC
# task                tokenizer
# bace_classification own_atom_isomers              0.2      norm  0.629348
#                     own_atom_standard             0.2      norm  0.629529
#                     own_trained_isomers           0.2      norm  0.628986
#                     own_trained_standard          0.2      norm  0.629167
#                     selfies_atom_isomers          0.2      norm  0.815580
#                     selfies_atom_standard         0.2      norm  0.809420
#                     selfies_trained_isomers       0.2      norm  0.779891
#                     selfies_trained_standard      0.2      norm  0.798370
#                     smiles_atom_isomers           0.2      norm  0.781703
#                     smiles_atom_standard          0.2      norm  0.800725
#                     smiles_trained_isomers        0.2      norm  0.792210
#                     smiles_trained_standard       0.2      norm  0.697826
# bbbp                own_atom_isomers              0.2      norm  0.567396
#                     own_atom_standard             0.2      norm  0.563638
#                     own_trained_isomers           0.2      norm  0.570045
#                     own_trained_standard          0.2      norm  0.567348
#                     selfies_atom_isomers          0.2      norm  0.682050
#                     selfies_atom_standard         0.2      norm  0.677522
#                     selfies_trained_isomers       0.2      norm  0.677137
#                     selfies_trained_standard      0.2      norm  0.683496
#                     smiles_atom_isomers           0.2      norm  0.711822
#                     smiles_atom_standard          0.2      norm  0.720301
#                     smiles_trained_isomers        0.2      norm  0.684266
#                     smiles_trained_standard       0.2      norm  0.708546
# clintox             own_atom_isomers              0.2      norm  0.540942
#                     own_atom_standard             0.2      norm  0.538768
#                     own_trained_isomers           0.2      norm  0.496377
#                     own_trained_standard          0.2      norm  0.493478
#                     selfies_atom_isomers          0.2      norm  0.867391
#                     selfies_atom_standard         0.2      norm  0.788406
#                     selfies_trained_isomers       0.2      norm  0.829710
#                     selfies_trained_standard      0.2      norm  0.747826
#                     smiles_atom_isomers           0.2      norm  0.872464
#                     smiles_atom_standard          0.2      norm  0.850000
#                     smiles_trained_isomers        0.2      norm  0.610145
#                     smiles_trained_standard       0.2      norm  0.678986
# hiv                 own_atom_isomers              0.2      norm  0.534411
#                     own_atom_standard             0.2      norm  0.542067
#                     own_trained_isomers           0.2      norm  0.534621
#                     own_trained_standard          0.2      norm  0.534621
#                     selfies_atom_isomers          0.2      norm  0.758069
#                     selfies_atom_standard         0.2      norm  0.771652
#                     selfies_trained_isomers       0.2      norm  0.740997
#                     selfies_trained_standard      0.2      norm  0.736161
#                     smiles_atom_isomers           0.2      norm  0.764685
#                     smiles_atom_standard          0.2      norm  0.740219
#                     smiles_trained_isomers        0.2      norm  0.769033
#                     smiles_trained_standard       0.2      norm  0.781852
# tox21               own_atom_isomers              0.2      norm  0.572926
#                     own_atom_standard             0.2      norm  0.565689
#                     own_trained_isomers           0.2      norm  0.562032
#                     own_trained_standard          0.2      norm  0.558208
#                     selfies_atom_isomers          0.2      norm  0.680107
#                     selfies_atom_standard         0.2      norm  0.685725
#                     selfies_trained_isomers       0.2      norm  0.712196
#                     selfies_trained_standard      0.2      norm  0.688124
#                     smiles_atom_isomers           0.2      norm  0.659605
#                     smiles_atom_standard          0.2      norm  0.664287
#                     smiles_trained_isomers        0.2      norm  0.674645
#                     smiles_trained_standard       0.2      norm  0.665789

# %%
from plotting import plot_scores
columns = list(regression_scores.columns[-3:])
columns.extend(regression_scores.columns[:-3])
tasks = regression_scores.task.unique()
tokenizers = regression_scores.tokenizer.unique()
scores = {}
for task in tasks:
    for tokenizer in tokenizers:
        scores[tokenizer] = scores.get(tokenizer, []) + [max(regression_scores[(regression_scores["tokenizer"]==tokenizer)&(regression_scores["task"]== task)]["rectified_mean_squared_error"])]
plot_scores(scores, tasks, "RMSE", Path("test/regression_report.svg"))

# %%
from IPython.display import SVG, display
from pathlib import Path

def show_svg():
    
    display(SVG(Path("test/test_pca.svg")))
    display(SVG(Path("test/test_umap.svg")))
        
show_svg()

# %%
max(classification_scores[(classification_scores["tokenizer"]=="smiles_atom")&(classification_scores["task"]== "hiv")]["ROC_AUC"])

# %%
import pandas as pd
from constants import TOKENIZER_SUFFIXES, PROJECT_PATH
pd.options.display.float_format = '{:,.3f}'.format
dfs = []
for task in ["lef"]:
    for tokenizer in ["selfies_atom", "selfies_sentencepiece", "smiles_sentencepiece"]:
        dfs.append(pd.read_csv(PROJECT_PATH/"reaction_prediction_beam_neu"/task/tokenizer/"output.csv"))
df = pd.concat(dfs)
df["top_perc_0"]=0
df["valid_perc_0"]=0
df["unk_perc_0"]=0
for i in range(1,11):
    df["top_perc_"+str(i)] =df["top_"+str(i)]/df["all_samples"]+df["top_perc_"+str(i-1)]
    df["valid_perc_"+str(i)] =df["valid_"+str(i)]/df["all_samples"]
    df["unk_perc_"+str(i)] =df["unk_"+str(i)]/df["all_samples"]
df.sort_values(["task", "model"])[[i for i in df.columns if (("perc" in i) and ("0" not in i))or i in ["model", "task"]]].to_markdown()

# %%
descriptors = [ 'NumAliphaticCarbocycles',
 'NumAliphaticHeterocycles',
 'NumAliphaticRings',
 'NumAromaticCarbocycles',
 'NumAromaticHeterocycles',
 'NumAromaticRings',
 'NumHAcceptors',
 'NumHDonors',
 'NumHeteroatoms',
 'NumRotatableBonds',
 'NumSaturatedCarbocycles',
 'NumSaturatedHeterocycles',
 'NumSaturatedRings',
 'RingCount',]
indexes = [str(DESCRIPTORS.index(descriptor)) for descriptor in descriptors]
test = pd.read_csv("processed/10m_deduplicated.csv", skiprows=0, usecols=indexes)
for index, descriptor in enumerate(descriptors):
    amount = sum(test[indexes[index]].gt(0))
    print(f"The stats for descriptor {descriptor}")
    print(f"Amount of mols with trait: {amount}, mols without trait: {len(test)-amount}")
    print(f"This is {amount/len(test):.3f}, mols without trait: {1-amount/len(test):.3f}")

# %%
import pandas as pd
from constants import DESCRIPTORS

descriptors = [
 'NumAliphaticHeterocycles',
 'NumAromaticHeterocycles',
 'NumSaturatedHeterocycles',]
indexes = [str(DESCRIPTORS.index(descriptor)) for descriptor in descriptors]
test = pd.read_csv("processed/10m_deduplicated.csv", skiprows=0, usecols=indexes)

amount = sum((test[indexes[0]]+test[indexes[1]]+test[indexes[2]]).gt(0))
print(f"The stats for descriptor heterocycles")
print(f"Amount of mols with trait: {amount}, mols without trait: {len(test)-amount}")
print(f"This is {amount/len(test):.3f}, mols without trait: {1-amount/len(test):.3f}")
